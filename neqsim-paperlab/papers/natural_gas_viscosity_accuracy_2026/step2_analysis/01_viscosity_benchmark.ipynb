# %% [markdown]
# # Natural-gas viscosity benchmark (PaperLab workflow)

# %%
from pathlib import Path
import json
import pandas as pd

# %%
task_dir = Path.cwd().parents[0]
results_csv = task_dir / 'results' / 'benchmark_point_results.csv'
summary_json = task_dir / 'results' / 'benchmark_summary.json'
df = pd.read_csv(results_csv)
df

# %%
with open(summary_json, 'r') as f:
    summary = json.load(f)
summary
